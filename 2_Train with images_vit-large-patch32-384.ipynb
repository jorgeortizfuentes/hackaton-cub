# %%
token = "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"

from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model_checkpoint = "google/vit-large-patch32-384" # pre-trained model from which to fine-tune
#model_checkpoint = "google/vit-base-patch16-224"
#model_checkpoint = "openai/clip-vit-base-patch32"
batch_size = 16 # batch size for training and evaluation
name_model = "vit-large-patch32-384_finetuning"

# %% [markdown]
# ## Fine-tuning a model on an image classification task

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/tiger_image.png" alt="drawing" width="600"/>

# %% [markdown]
# ### Loading the dataset

# %%
from datasets import load_dataset 
dataset = load_dataset("imagefolder", data_files="https://madm.dfki.de/files/sentinel/EuroSAT.zip")
# Out:
# Using custom data configuration default-71c8f80171b09b95
# Found cached dataset imagefolder (/home/jlortiz/.cache/huggingface/datasets/imagefolder/default-71c8f80171b09b95/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
type(dataset["train"][0]['image'])
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import pandas as pd
import swifter

info = "info_CUB.csv"
df = pd.read_csv(info, sep=";")

# Convert labels (str) to int
#df["label"] = df["label"].astype("category").cat.codes

# Convert df["labels"] to label2id and id2label
label2id = {k: v for v, k in enumerate(df["label"].unique())}
id2label = {v: k for k, v in label2id.items()}
df["label"] = df["label"].map(label2id)


columns = ["image", "label"]

data_train = df[df["train"] == 1][columns]
data_test = df[df["train"] == 0][columns]

# %%
from datasets import Dataset, Image

train_dataset = Dataset.from_pandas(data_train).remove_columns(["__index_level_0__"]).cast_column("image", Image())
test_dataset = Dataset.from_pandas(data_test).remove_columns(["__index_level_0__"]).cast_column("image", Image())

# Cast image to Image type
#train_dataset = train_dataset.map(lambda x: {"image": Image(x["image"])}, remove_columns=["image"])
#test_dataset = test_dataset.map(lambda x: {"image": Image(x["image"])}, remove_columns=["image"])

# %%
# Split train in train and validation
train_dataset = train_dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
eval_dataset = train_dataset["test"]
train_dataset = train_dataset["train"]

# %% [markdown]
# ### Preprocessing the data

# %%
from transformers import AutoFeatureExtractor

feature_extractor = AutoFeatureExtractor.from_pretrained(model_checkpoint)
feature_extractor
# Out:
# 2022-11-24 22:41:04.211096: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-24 22:41:04.211125: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "size": 384
# }

# %%
from torchvision.transforms import RandomResizedCrop, Compose, Normalize, ToTensor
normalize = Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
_transforms = Compose([RandomResizedCrop(feature_extractor.size), ToTensor(), normalize])

# # Data augmentation (only images in training)
# _transforms = Compose([
#   transforms.RandomResizedCrop(224, scale=(0.2, 1.)),
#   transforms.RandomHorizontalFlip(),
#   transforms.ColorJitter(0.4, 0.4, 0.4, 0.1),  # not strengthened
#   transforms.RandomGrayscale(p=0.1),
#   transforms.ToTensor(),
#   transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
# ])

# train_dataset = train_dataset.map(lambda x: {"image": data_augmentation(x["image"])}, remove_columns=["image"])

def transforms(examples):
    examples["pixel_values"] = [_transforms(img.convert("RGB")) for img in examples["image"]]
    del examples["image"]
    return examples

# %% [markdown]
# Next, we can preprocess our dataset by applying these functions. We will use the `set_transform` functionality, which allows to apply the functions above on-the-fly (meaning that they will only be applied when the images are loaded in RAM).

# %%
train_dataset = train_dataset.with_transform(transforms)
eval_dataset = eval_dataset.with_transform(transforms)
test_dataset = test_dataset.with_transform(transforms)

# %%
from transformers import DefaultDataCollator
data_collator = DefaultDataCollator()

# %%
import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")

# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %% [markdown]
# Now that our data is ready, we can download the pretrained model and fine-tune it. For classification we use the `AutoModelForImageClassification` class. Calling the `from_pretrained` method on it will download and cache the weights for us. As the label ids and the number of labels are dataset dependent, we pass `label2id`, and `id2label` alongside the `model_checkpoint` here. This will make sure a custom classification head will be created (with a custom number of output neurons).
#
# NOTE: in case you're planning to fine-tune an already fine-tuned checkpoint, like [facebook/convnext-tiny-224](https://huggingface.co/facebook/convnext-tiny-224) (which has already been fine-tuned on ImageNet-1k), then you need to provide the additional argument `ignore_mismatched_sizes=True` to the `from_pretrained` method. This will make sure the output head (with 1000 output neurons) is thrown away and replaced by a new, randomly initialized classification head that includes a custom number of output neurons. You don't need to specify this argument in case the pre-trained model doesn't include a head.

# %%
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

model = AutoModelForImageClassification.from_pretrained(
    model_checkpoint, 
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes = True, # provide this in case you're planning to fine-tune an already fine-tuned checkpoint
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-large-patch32-384 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 1024]) in the checkpoint and torch.Size([200, 1024]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([200]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
args = TrainingArguments(
    name_model,
    remove_unused_columns=False,
    evaluation_strategy = "steps",
    save_strategy = "steps",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=100,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    fp16=True,
    save_steps=500,
    eval_steps=500,
)

# %%
trainer = Trainer(
    model=model,
    args=args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Using cuda_amp half precision backend
# ***** Running training *****
#   Num examples = 5371
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 16800
#   Number of trainable parameters = 305812680
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='3206' max='16800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3206/16800 59:39 < 4:13:07, 0.90 it/s, Epoch 19.08/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.764700</td>
#       <td>3.856550</td>
#       <td>0.460637</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.960500</td>
#       <td>1.270464</td>
#       <td>0.765494</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.494600</td>
#       <td>0.920397</td>
#       <td>0.780570</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.371100</td>
#       <td>0.876096</td>
#       <td>0.780570</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.204500</td>
#       <td>0.863371</td>
#       <td>0.782245</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.199300</td>
#       <td>0.919678</td>
#       <td>0.767169</td>
#     </tr>
#     <tr>
#       <td>3205</td>
#       <td>0.391200</td>
#       <td>0.823218</td>
#       <td>0.794502</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='182' max='182' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [182/182 02:06]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 597
#   Batch size = 32
# Saving model checkpoint to vit-large-patch32-384_finetuning/checkpoint-500
# Configuration saved in vit-large-patch32-384_finetuning/checkpoint-500/config.json
# Model weights saved in vit-large-patch32-384_finetuning/checkpoint-500/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/checkpoint-500/preprocessor_config.json
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 597
#   Batch size = 32
# Saving model checkpoint to vit-large-patch32-384_finetuning/checkpoint-1000
# Configuration saved in vit-large-patch32-384_finetuning/checkpoint-1000/config.json
# Model weights saved in vit-large-patch32-384_finetuning/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/checkpoint-1000/preprocessor_config.json
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 597
#   Batch size = 32
# Saving model checkpoint to vit-large-patch32-384_finetuning/checkpoint-1500
# Configuration saved in vit-large-patch32-384_finetuning/checkpoint-1500/config.json
# Model weights saved in vit-large-patch32-384_finetuning/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/checkpoint-1500/preprocessor_config.json
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 597
#   Batch size = 32
# Saving model checkpoint to vit-large-patch32-384_finetuning/checkpoint-2000
# Configuration saved in vit-large-patch32-384_finetuning/checkpoint-2000/config.json
# Model weights saved in vit-large-patch32-384_finetuning/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/checkpoint-2000/preprocessor_config.json
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 597
#   Batch size = 32
# Saving model checkpoint to vit-large-patch32-384_finetuning/checkpoint-2500
# Configuration saved in vit-large-patch32-384_finetuning/checkpoint-2500/config.json
# Model weights saved in vit-large-patch32-384_finetuning/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/checkpoint-2500/preprocessor_config.json
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 597
#   Batch size = 32
# Saving model checkpoint to vit-large-patch32-384_finetuning/checkpoint-3000
# Configuration saved in vit-large-patch32-384_finetuning/checkpoint-3000/config.json
# Model weights saved in vit-large-patch32-384_finetuning/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/checkpoint-3000/preprocessor_config.json
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jlortiz/hackaton-cub/2_Train with images_vit-large-patch32-384.ipynb Cell 23 in <cell line: 11>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bgate.dcc.uchile.cl/home/jlortiz/hackaton-cub/2_Train%20with%20images_vit-large-patch32-384.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> trainer = Trainer(
#       <a href='vscode-notebook-cell://ssh-remote%2Bgate.dcc.uchile.cl/home/jlortiz/hackaton-cub/2_Train%20with%20images_vit-large-patch32-384.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     model=model,
#       <a href='vscode-notebook-cell://ssh-remote%2Bgate.dcc.uchile.cl/home/jlortiz/hackaton-cub/2_Train%20with%20images_vit-large-patch32-384.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     args=args,
#    (...)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgate.dcc.uchile.cl/home/jlortiz/hackaton-cub/2_Train%20with%20images_vit-large-patch32-384.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     compute_metrics=compute_metrics,
#       <a href='vscode-notebook-cell://ssh-remote%2Bgate.dcc.uchile.cl/home/jlortiz/hackaton-cub/2_Train%20with%20images_vit-large-patch32-384.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> )
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgate.dcc.uchile.cl/home/jlortiz/hackaton-cub/2_Train%20with%20images_vit-large-patch32-384.ipynb#X44sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> trainer.train()
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/trainer.py:1501, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1496     self.model_wrapped = self.model
#    1498 inner_training_loop = find_executable_batch_size(
#    1499     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1500 )
# -> 1501 return inner_training_loop(
#    1502     args=args,
#    1503     resume_from_checkpoint=resume_from_checkpoint,
#    1504     trial=trial,
#    1505     ignore_keys_for_eval=ignore_keys_for_eval,
#    1506 )
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/trainer.py:1749, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1747         tr_loss_step = self.training_step(model, inputs)
#    1748 else:
# -> 1749     tr_loss_step = self.training_step(model, inputs)
#    1751 if (
#    1752     args.logging_nan_inf_filter
#    1753     and not is_torch_tpu_available()
#    1754     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1755 ):
#    1756     # if loss is nan or inf simply add the average of previous logged losses
#    1757     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/trainer.py:2508, in Trainer.training_step(self, model, inputs)
#    2505     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2507 with self.compute_loss_context_manager():
# -> 2508     loss = self.compute_loss(model, inputs)
#    2510 if self.args.n_gpu > 1:
#    2511     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/trainer.py:2540, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2538 else:
#    2539     labels = None
# -> 2540 outputs = model(**inputs)
#    2541 # Save past state if it exists
#    2542 # TODO: this needs to be fixed and made cleaner later.
#    2543 if self.args.past_index >= 0:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/data_parallel.py:170, in DataParallel.forward(self, *inputs, **kwargs)
#     168 if len(self.device_ids) == 1:
#     169     return self.module(*inputs[0], **kwargs[0])
# --> 170 replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     171 outputs = self.parallel_apply(replicas, inputs, kwargs)
#     172 return self.gather(outputs, self.output_device)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/data_parallel.py:175, in DataParallel.replicate(self, module, device_ids)
#     174 def replicate(self, module, device_ids):
# --> 175     return replicate(module, device_ids, not torch.is_grad_enabled())
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/replicate.py:91, in replicate(network, devices, detach)
#      89 params = list(network.parameters())
#      90 param_indices = {param: idx for idx, param in enumerate(params)}
# ---> 91 param_copies = _broadcast_coalesced_reshape(params, devices, detach)
#      93 buffers = list(network.buffers())
#      94 buffers_rg = []
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/replicate.py:71, in _broadcast_coalesced_reshape(tensors, devices, detach)
#      68 else:
#      69     # Use the autograd function to broadcast if not detach
#      70     if len(tensors) > 0:
# ---> 71         tensor_copies = Broadcast.apply(devices, *tensors)
#      72         return [tensor_copies[i:i + len(tensors)]
#      73                 for i in range(0, len(tensor_copies), len(tensors))]
#      74     else:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:23, in Broadcast.forward(ctx, target_gpus, *inputs)
#      21 ctx.num_inputs = len(inputs)
#      22 ctx.input_device = inputs[0].get_device()
# ---> 23 outputs = comm.broadcast_coalesced(inputs, ctx.target_gpus)
#      24 non_differentiables = []
#      25 for idx, input_requires_grad in enumerate(ctx.needs_input_grad[1:]):
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/comm.py:58, in broadcast_coalesced(tensors, devices, buffer_size)
#      56 devices = [_get_device_index(d) for d in devices]
#      57 tensors = [_handle_complex(t) for t in tensors]
# ---> 58 return torch._C._broadcast_coalesced(tensors, devices, buffer_size)
#
# KeyboardInterrupt:

# %%
# Eval on test set
trainer.evaluate(test_dataset)
# Out:
# ***** Running Evaluation *****
#   Num examples = 5820
#   Batch size = 32
# {'eval_loss': 0.8232176303863525, 'eval_accuracy': 0.7945017182130584}

# %%
# Sklearn classification report
from sklearn.metrics import classification_report
preds = trainer.predict(test_dataset)
preds = np.argmax(preds.predictions, axis=1)
print(classification_report(df[df["train"] == 0]["label"], preds))
# Out:
# ***** Running Prediction *****
#   Num examples = 5820
#   Batch size = 32
# /home/jlortiz/anaconda3/envs/py310/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#          162       0.97      0.97      0.97        35
#          163       0.45      0.73      0.56        26
#          164       0.76      0.59      0.67        32
#          165       0.94      0.91      0.92        33
#          166       0.80      0.57      0.67        28
#          167       0.92      0.80      0.86        30
#          168       0.70      0.93      0.80        28
#          169       0.96      0.74      0.84        35
#          170       0.92      0.73      0.81        33
#          171       0.83      0.80      0.82        25
#          172       0.77      0.80      0.78        25
#          173       0.93      0.84      0.89        32
#          174       0.74      0.91      0.82        32
#          175       0.96      0.92      0.94        24
#          176       0.71      0.89      0.79        27
#          177       0.97      0.88      0.92        32
#          178       0.61      0.50      0.55        22
#          179       0.85      0.93      0.89        30
#          180       0.86      0.63      0.73        30
#          181       0.57      0.84      0.68        31
#          182       0.71      0.74      0.72        23
#          183       0.67      0.71      0.69        31
#          184       0.62      0.79      0.70        29
#          185       0.70      0.88      0.78        26
#          186       0.68      0.70      0.69        30
#          187       0.94      0.86      0.90        35
#          188       0.96      0.86      0.91        29
#          189       1.00      0.93      0.96        29
#          190       0.83      0.86      0.85        29
#          191       0.95      0.76      0.84        25
#          192       0.96      0.88      0.92        25
#          193       0.94      0.52      0.67        33
#          194       0.71      0.89      0.79        27
#          195       0.60      0.69      0.64        39
#          196       0.93      0.54      0.68        26
#          197       0.53      0.27      0.36        33
#          198       0.70      0.83      0.76        36
#          199       0.91      0.83      0.87        24
#
#     accuracy                           0.79      5820
#    macro avg       0.81      0.79      0.79      5820
# weighted avg       0.81      0.79      0.79      5820

# %%
# Save model
from transformers import AutoConfig
config = AutoConfig.from_pretrained(model_checkpoint, label2id=label2id, id2label=id2label)
config.save_pretrained(name_model)
trainer.model.save_pretrained(name_model)

# Save feature_extractor
feature_extractor.save_pretrained(name_model)
# Out:
# loading configuration file config.json from cache at /home/jlortiz/.cache/huggingface/hub/models--google--vit-large-patch32-384/snapshots/a2b30ad36d02e99f045cd2ecfc71e0ae16991efa/config.json
# Model config ViTConfig {
#   "_name_or_path": "google/vit-large-patch32-384",
#   "architectures": [
#     "ViTForImageClassification"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 1024,
#   "id2label": {
#     "0": "001.Black_footed_Albatross",
#     "1": "003.Sooty_Albatross",
#     "2": "004.Groove_billed_Ani",
#     "3": "005.Crested_Auklet",
#     "4": "006.Least_Auklet",
#     "5": "007.Parakeet_Auklet",
#     "6": "008.Rhinoceros_Auklet",
#     "7": "009.Brewer_Blackbird",
#     "8": "010.Red_winged_Blackbird",
#     "9": "014.Indigo_Bunting",
#     "10": "015.Lazuli_Bunting",
#     "11": "016.Painted_Bunting",
#     "12": "017.Cardinal",
#     "13": "018.Spotted_Catbird",
#     "14": "020.Yellow_breasted_Chat",
#     "15": "022.Chuck_will_Widow",
#     "16": "024.Red_faced_Cormorant",
#     "17": "025.Pelagic_Cormorant",
#     "18": "026.Bronzed_Cowbird",
#     "19": "027.Shiny_Cowbird",
#     "20": "030.Fish_Crow",
#     "21": "032.Mangrove_Cuckoo",
#     "22": "033.Yellow_billed_Cuckoo",
#     "182": "130.Tree_Sparrow",
#     "183": "155.Warbling_Vireo",
#     "184": "167.Hooded_Warbler",
#     "185": "172.Nashville_Warbler",
#     "186": "173.Orange_crowned_Warbler",
#     "187": "191.Red_headed_Woodpecker",
#     "188": "074.Florida_Jay",
#     "189": "075.Green_Jay",
#     "190": "154.Red_eyed_Vireo",
#     "191": "162.Canada_Warbler",
#     "192": "169.Magnolia_Warbler",
#     "193": "179.Tennessee_Warbler",
#     "194": "083.White_breasted_Kingfisher",
#     "195": "064.Ring_billed_Gull",
#     "196": "069.Rufous_Hummingbird",
#     "197": "144.Common_Tern",
#     "198": "196.House_Wren",
#     "199": "061.Heermann_Gull"
#   },
#   "image_size": 384,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "label2id": {
#     "001.Black_footed_Albatross": 0,
#     "002.Laysan_Albatross": 109,
#     "003.Sooty_Albatross": 1,
#     "004.Groove_billed_Ani": 2,
#     "005.Crested_Auklet": 3,
#     "006.Least_Auklet": 4,
#     "007.Parakeet_Auklet": 5,
#     "008.Rhinoceros_Auklet": 6,
#     "009.Brewer_Blackbird": 7,
#     "010.Red_winged_Blackbird": 8,
#     "011.Rusty_Blackbird": 110,
#     "012.Yellow_headed_Blackbird": 111,
#     "013.Bobolink": 155,
#     "014.Indigo_Bunting": 9,
#     "015.Lazuli_Bunting": 10,
#     "016.Painted_Bunting": 11,
#     "017.Cardinal": 12,
#     "018.Spotted_Catbird": 13,
#     "019.Gray_Catbird": 156,
#     "020.Yellow_breasted_Chat": 14,
#     "021.Eastern_Towhee": 112,
#     "022.Chuck_will_Widow": 15,
#     "023.Brandt_Cormorant": 113,
#     "024.Red_faced_Cormorant": 16,
#     "025.Pelagic_Cormorant": 17,
#     "026.Bronzed_Cowbird": 18,
#     "027.Shiny_Cowbird": 19,
#     "028.Brown_Creeper": 157,
#     "029.American_Crow": 158,
#     "030.Fish_Crow": 20,
#     "031.Black_billed_Cuckoo": 114,
#     "032.Mangrove_Cuckoo": 21,
#     "033.Yellow_billed_Cuckoo": 22,
#     "034.Gray_crowned_Rosy_Finch": 23,
#     "035.Purple_Finch": 115,
#     "036.Northern_Flicker": 159,
#     "037.Acadian_Flycatcher": 24,
#     "038.Great_Crested_Flycatcher": 25,
#     "039.Least_Flycatcher": 26,
#     "040.Olive_sided_Flycatcher": 116,
#     "041.Scissor_tailed_Flycatcher": 117,
#     "042.Vermilion_Flycatcher": 160,
#     "043.Yellow_bellied_Flycatcher": 27,
#     "044.Frigatebird": 118,
#     "045.Northern_Fulmar": 28,
#     "046.Gadwall": 29,
#     "047.American_Goldfinch": 119,
#     "048.European_Goldfinch": 177,
#     "049.Boat_tailed_Grackle": 120,
#     "050.Eared_Grebe": 30,
#     "051.Horned_Grebe": 31,
#     "052.Pied_billed_Grebe": 121,
#     "053.Western_Grebe": 161,
#     "054.Blue_Grosbeak": 32,
#     "055.Evening_Grosbeak": 162,
#     "056.Pine_Grosbeak": 122,
#     "057.Rose_breasted_Grosbeak": 33,
#     "058.Pigeon_Guillemot": 123,
#     "059.California_Gull": 34,
#     "060.Glaucous_winged_Gull": 124,
#     "061.Heermann_Gull": 199,
#     "062.Herring_Gull": 35,
#     "063.Ivory_Gull": 36,
#     "064.Ring_billed_Gull": 195,
#     "065.Slaty_backed_Gull": 178,
#     "066.Western_Gull": 163,
#     "067.Anna_Hummingbird": 164,
#     "068.Ruby_throated_Hummingbird": 37,
#     "069.Rufous_Hummingbird": 196,
#     "070.Green_Violetear": 125,
#     "071.Long_tailed_Jaeger": 38,
#     "072.Pomarine_Jaeger": 39,
#     "073.Blue_Jay": 40,
#     "074.Florida_Jay": 188,
#     "075.Green_Jay": 189,
#     "076.Dark_eyed_Junco": 41,
#     "077.Tropical_Kingbird": 42,
#     "078.Gray_Kingbird": 43,
#     "079.Belted_Kingfisher": 126,
#     "080.Green_Kingfisher": 44,
#     "081.Pied_Kingfisher": 179,
#     "082.Ringed_Kingfisher": 127,
#     "083.White_breasted_Kingfisher": 194,
#     "084.Red_legged_Kittiwake": 45,
#     "085.Horned_Lark": 46,
#     "086.Pacific_Loon": 47,
#     "087.Mallard": 128,
#     "088.Western_Meadowlark": 165,
#     "089.Hooded_Merganser": 48,
#     "090.Red_breasted_Merganser": 49,
#     "091.Mockingbird": 50,
#     "092.Nighthawk": 129,
#     "093.Clark_Nutcracker": 130,
#     "094.White_breasted_Nuthatch": 51,
#     "095.Baltimore_Oriole": 131,
#     "096.Hooded_Oriole": 52,
#     "097.Orchard_Oriole": 132,
#     "098.Scott_Oriole": 53,
#     "099.Ovenbird": 54,
#     "100.Brown_Pelican": 55,
#     "101.White_Pelican": 56,
#     "102.Western_Wood_Pewee": 57,
#     "103.Sayornis": 58,
#     "104.American_Pipit": 59,
#     "105.Whip_poor_Will": 60,
#     "106.Horned_Puffin": 61,
#     "107.Common_Raven": 62,
#     "108.White_necked_Raven": 63,
#     "109.American_Redstart": 133,
#     "110.Geococcyx": 64,
#     "111.Loggerhead_Shrike": 65,
#     "112.Great_Grey_Shrike": 66,
#     "113.Baird_Sparrow": 67,
#     "114.Black_throated_Sparrow": 68,
#     "115.Brewer_Sparrow": 69,
#     "116.Chipping_Sparrow": 70,
#     "117.Clay_colored_Sparrow": 71,
#     "118.House_Sparrow": 72,
#     "119.Field_Sparrow": 166,
#     "120.Fox_Sparrow": 73,
#     "121.Grasshopper_Sparrow": 134,
#     "122.Harris_Sparrow": 74,
#     "123.Henslow_Sparrow": 75,
#     "124.Le_Conte_Sparrow": 76,
#     "125.Lincoln_Sparrow": 77,
#     "126.Nelson_Sharp_tailed_Sparrow": 180,
#     "127.Savannah_Sparrow": 181,
#     "128.Seaside_Sparrow": 167,
#     "129.Song_Sparrow": 78,
#     "130.Tree_Sparrow": 182,
#     "131.Vesper_Sparrow": 135,
#     "132.White_crowned_Sparrow": 79,
#     "133.White_throated_Sparrow": 136,
#     "134.Cape_Glossy_Starling": 80,
#     "135.Bank_Swallow": 81,
#     "136.Barn_Swallow": 168,
#     "137.Cliff_Swallow": 169,
#     "138.Tree_Swallow": 137,
#     "139.Scarlet_Tanager": 138,
#     "140.Summer_Tanager": 82,
#     "141.Artic_Tern": 139,
#     "142.Black_Tern": 83,
#     "143.Caspian_Tern": 84,
#     "144.Common_Tern": 197,
#     "145.Elegant_Tern": 140,
#     "146.Forsters_Tern": 85,
#     "147.Least_Tern": 141,
#     "148.Green_tailed_Towhee": 86,
#     "149.Brown_Thrasher": 87,
#     "150.Sage_Thrasher": 170,
#     "151.Black_capped_Vireo": 88,
#     "152.Blue_headed_Vireo": 89,
#     "153.Philadelphia_Vireo": 90,
#     "154.Red_eyed_Vireo": 190,
#     "155.Warbling_Vireo": 183,
#     "156.White_eyed_Vireo": 142,
#     "157.Yellow_throated_Vireo": 91,
#     "158.Bay_breasted_Warbler": 143,
#     "159.Black_and_white_Warbler": 92,
#     "160.Black_throated_Blue_Warbler": 93,
#     "161.Blue_winged_Warbler": 144,
#     "162.Canada_Warbler": 191,
#     "163.Cape_May_Warbler": 171,
#     "164.Cerulean_Warbler": 94,
#     "165.Chestnut_sided_Warbler": 172,
#     "166.Golden_winged_Warbler": 145,
#     "167.Hooded_Warbler": 184,
#     "168.Kentucky_Warbler": 95,
#     "169.Magnolia_Warbler": 192,
#     "170.Mourning_Warbler": 146,
#     "171.Myrtle_Warbler": 173,
#     "172.Nashville_Warbler": 185,
#     "173.Orange_crowned_Warbler": 186,
#     "174.Palm_Warbler": 96,
#     "175.Pine_Warbler": 97,
#     "176.Prairie_Warbler": 98,
#     "177.Prothonotary_Warbler": 147,
#     "178.Swainson_Warbler": 99,
#     "179.Tennessee_Warbler": 193,
#     "180.Wilson_Warbler": 100,
#     "181.Worm_eating_Warbler": 148,
#     "182.Yellow_Warbler": 174,
#     "183.Northern_Waterthrush": 149,
#     "184.Louisiana_Waterthrush": 101,
#     "185.Bohemian_Waxwing": 102,
#     "186.Cedar_Waxwing": 103,
#     "187.American_Three_toed_Woodpecker": 104,
#     "188.Pileated_Woodpecker": 150,
#     "189.Red_bellied_Woodpecker": 105,
#     "190.Red_cockaded_Woodpecker": 106,
#     "191.Red_headed_Woodpecker": 187,
#     "192.Downy_Woodpecker": 151,
#     "193.Bewick_Wren": 107,
#     "194.Cactus_Wren": 175,
#     "195.Carolina_Wren": 152,
#     "196.House_Wren": 198,
#     "197.Marsh_Wren": 153,
#     "198.Rock_Wren": 176,
#     "199.Winter_Wren": 154,
#     "200.Common_Yellowthroat": 108
#   },
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 16,
#   "num_channels": 3,
#   "num_hidden_layers": 24,
#   "patch_size": 32,
#   "qkv_bias": true,
#   "transformers_version": "4.24.0"
# }
#
# Configuration saved in vit-large-patch32-384_finetuning/config.json
# Configuration saved in vit-large-patch32-384_finetuning/config.json
# Model weights saved in vit-large-patch32-384_finetuning/pytorch_model.bin
# Feature extractor saved in vit-large-patch32-384_finetuning/preprocessor_config.json
# ['vit-large-patch32-384_finetuning/preprocessor_config.json']

# %%
# Get embeddings from the model
from transformers import AutoTokenizer, AutoModel
feature_extractor = AutoFeatureExtractor.from_pretrained(name_model)
model = AutoModel.from_pretrained(name_model)
# Out:
# loading configuration file images_model/preprocessor_config.json
# Feature extractor ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 3,
#   "size": 224
# }
#
# loading configuration file images_model/config.json
# Model config SwinConfig {
#   "_name_or_path": "images_model",
#   "architectures": [
#     "SwinForImageClassification"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "depths": [
#     2,
#     2,
#     6,
#     2
#   ],
#   "drop_path_rate": 0.1,
#   "embed_dim": 96,
#   "encoder_stride": 32,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "001.Black_footed_Albatross",
#     "1": "003.Sooty_Albatross",
#     "2": "004.Groove_billed_Ani",
#     "3": "005.Crested_Auklet",
#     "4": "006.Least_Auklet",
#     "5": "007.Parakeet_Auklet",
#     "6": "008.Rhinoceros_Auklet",
#     "7": "009.Brewer_Blackbird",
#     "8": "010.Red_winged_Blackbird",
#     "9": "014.Indigo_Bunting",
#     "10": "015.Lazuli_Bunting",
#     "11": "016.Painted_Bunting",
#     "12": "017.Cardinal",
#     "13": "018.Spotted_Catbird",
#     "14": "020.Yellow_breasted_Chat",
#     "15": "022.Chuck_will_Widow",
#     "16": "024.Red_faced_Cormorant",
#     "17": "025.Pelagic_Cormorant",
#     "18": "026.Bronzed_Cowbird",
#     "19": "027.Shiny_Cowbird",
#     "20": "030.Fish_Crow",
#     "21": "032.Mangrove_Cuckoo",
#     "22": "033.Yellow_billed_Cuckoo",
#     "23": "034.Gray_crowned_Rosy_Finch",
#     "24": "037.Acadian_Flycatcher",
#     "25": "038.Great_Crested_Flycatcher",
#     "26": "039.Least_Flycatcher",
#     "27": "043.Yellow_bellied_Flycatcher",
#     "28": "045.Northern_Fulmar",
#     "29": "046.Gadwall",
#     "30": "050.Eared_Grebe",
#     "31": "051.Horned_Grebe",
#     "32": "054.Blue_Grosbeak",
#     "33": "057.Rose_breasted_Grosbeak",
#     "34": "059.California_Gull",
#     "35": "062.Herring_Gull",
#     "36": "063.Ivory_Gull",
#     "37": "068.Ruby_throated_Hummingbird",
#     "38": "071.Long_tailed_Jaeger",
#     "39": "072.Pomarine_Jaeger",
#     "40": "073.Blue_Jay",
#     "41": "076.Dark_eyed_Junco",
#     "42": "077.Tropical_Kingbird",
#     "43": "078.Gray_Kingbird",
#     "44": "080.Green_Kingfisher",
#     "45": "084.Red_legged_Kittiwake",
#     "46": "085.Horned_Lark",
#     "47": "086.Pacific_Loon",
#     "48": "089.Hooded_Merganser",
#     "49": "090.Red_breasted_Merganser",
#     "50": "091.Mockingbird",
#     "51": "094.White_breasted_Nuthatch",
#     "52": "096.Hooded_Oriole",
#     "53": "098.Scott_Oriole",
#     "54": "099.Ovenbird",
#     "55": "100.Brown_Pelican",
#     "56": "101.White_Pelican",
#     "57": "102.Western_Wood_Pewee",
#     "58": "103.Sayornis",
#     "59": "104.American_Pipit",
#     "60": "105.Whip_poor_Will",
#     "140": "145.Elegant_Tern",
#     "141": "147.Least_Tern",
#     "142": "156.White_eyed_Vireo",
#     "143": "158.Bay_breasted_Warbler",
#     "144": "161.Blue_winged_Warbler",
#     "145": "166.Golden_winged_Warbler",
#     "146": "170.Mourning_Warbler",
#     "147": "177.Prothonotary_Warbler",
#     "148": "181.Worm_eating_Warbler",
#     "149": "183.Northern_Waterthrush",
#     "150": "188.Pileated_Woodpecker",
#     "151": "192.Downy_Woodpecker",
#     "152": "195.Carolina_Wren",
#     "153": "197.Marsh_Wren",
#     "154": "199.Winter_Wren",
#     "155": "013.Bobolink",
#     "156": "019.Gray_Catbird",
#     "157": "028.Brown_Creeper",
#     "158": "029.American_Crow",
#     "159": "036.Northern_Flicker",
#     "160": "042.Vermilion_Flycatcher",
#     "161": "053.Western_Grebe",
#     "162": "055.Evening_Grosbeak",
#     "163": "066.Western_Gull",
#     "164": "067.Anna_Hummingbird",
#     "165": "088.Western_Meadowlark",
#     "166": "119.Field_Sparrow",
#     "167": "128.Seaside_Sparrow",
#     "168": "136.Barn_Swallow",
#     "169": "137.Cliff_Swallow",
#     "170": "150.Sage_Thrasher",
#     "171": "163.Cape_May_Warbler",
#     "172": "165.Chestnut_sided_Warbler",
#     "173": "171.Myrtle_Warbler",
#     "174": "182.Yellow_Warbler",
#     "175": "194.Cactus_Wren",
#     "176": "198.Rock_Wren",
#     "177": "048.European_Goldfinch",
#     "178": "065.Slaty_backed_Gull",
#     "179": "081.Pied_Kingfisher",
#     "180": "126.Nelson_Sharp_tailed_Sparrow",
#     "181": "127.Savannah_Sparrow",
#     "182": "130.Tree_Sparrow",
#     "183": "155.Warbling_Vireo",
#     "184": "167.Hooded_Warbler",
#     "185": "172.Nashville_Warbler",
#     "186": "173.Orange_crowned_Warbler",
#     "187": "191.Red_headed_Woodpecker",
#     "188": "074.Florida_Jay",
#     "189": "075.Green_Jay",
#     "190": "154.Red_eyed_Vireo",
#     "191": "162.Canada_Warbler",
#     "192": "169.Magnolia_Warbler",
#     "193": "179.Tennessee_Warbler",
#     "194": "083.White_breasted_Kingfisher",
#     "195": "064.Ring_billed_Gull",
#     "196": "069.Rufous_Hummingbird",
#     "197": "144.Common_Tern",
#     "198": "196.House_Wren",
#     "199": "061.Heermann_Gull"
#   },
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "label2id": {
#     "001.Black_footed_Albatross": 0,
#     "002.Laysan_Albatross": 109,
#     "003.Sooty_Albatross": 1,
#     "004.Groove_billed_Ani": 2,
#     "005.Crested_Auklet": 3,
#     "006.Least_Auklet": 4,
#     "007.Parakeet_Auklet": 5,
#     "008.Rhinoceros_Auklet": 6,
#     "009.Brewer_Blackbird": 7,
#     "010.Red_winged_Blackbird": 8,
#     "011.Rusty_Blackbird": 110,
#     "012.Yellow_headed_Blackbird": 111,
#     "013.Bobolink": 155,
#     "014.Indigo_Bunting": 9,
#     "015.Lazuli_Bunting": 10,
#     "016.Painted_Bunting": 11,
#     "017.Cardinal": 12,
#     "018.Spotted_Catbird": 13,
#     "019.Gray_Catbird": 156,
#     "020.Yellow_breasted_Chat": 14,
#     "021.Eastern_Towhee": 112,
#     "022.Chuck_will_Widow": 15,
#     "023.Brandt_Cormorant": 113,
#     "024.Red_faced_Cormorant": 16,
#     "025.Pelagic_Cormorant": 17,
#     "026.Bronzed_Cowbird": 18,
#     "027.Shiny_Cowbird": 19,
#     "028.Brown_Creeper": 157,
#     "029.American_Crow": 158,
#     "030.Fish_Crow": 20,
#     "031.Black_billed_Cuckoo": 114,
#     "032.Mangrove_Cuckoo": 21,
#     "033.Yellow_billed_Cuckoo": 22,
#     "034.Gray_crowned_Rosy_Finch": 23,
#     "035.Purple_Finch": 115,
#     "036.Northern_Flicker": 159,
#     "037.Acadian_Flycatcher": 24,
#     "038.Great_Crested_Flycatcher": 25,
#     "039.Least_Flycatcher": 26,
#     "040.Olive_sided_Flycatcher": 116,
#     "041.Scissor_tailed_Flycatcher": 117,
#     "042.Vermilion_Flycatcher": 160,
#     "043.Yellow_bellied_Flycatcher": 27,
#     "044.Frigatebird": 118,
#     "045.Northern_Fulmar": 28,
#     "046.Gadwall": 29,
#     "047.American_Goldfinch": 119,
#     "048.European_Goldfinch": 177,
#     "049.Boat_tailed_Grackle": 120,
#     "050.Eared_Grebe": 30,
#     "051.Horned_Grebe": 31,
#     "052.Pied_billed_Grebe": 121,
#     "053.Western_Grebe": 161,
#     "054.Blue_Grosbeak": 32,
#     "055.Evening_Grosbeak": 162,
#     "056.Pine_Grosbeak": 122,
#     "057.Rose_breasted_Grosbeak": 33,
#     "058.Pigeon_Guillemot": 123,
#     "059.California_Gull": 34,
#     "060.Glaucous_winged_Gull": 124,
#     "061.Heermann_Gull": 199,
#     "062.Herring_Gull": 35,
#     "063.Ivory_Gull": 36,
#     "064.Ring_billed_Gull": 195,
#     "065.Slaty_backed_Gull": 178,
#     "066.Western_Gull": 163,
#     "067.Anna_Hummingbird": 164,
#     "068.Ruby_throated_Hummingbird": 37,
#     "069.Rufous_Hummingbird": 196,
#     "070.Green_Violetear": 125,
#     "071.Long_tailed_Jaeger": 38,
#     "072.Pomarine_Jaeger": 39,
#     "073.Blue_Jay": 40,
#     "074.Florida_Jay": 188,
#     "075.Green_Jay": 189,
#     "076.Dark_eyed_Junco": 41,
#     "077.Tropical_Kingbird": 42,
#     "078.Gray_Kingbird": 43,
#     "079.Belted_Kingfisher": 126,
#     "080.Green_Kingfisher": 44,
#     "081.Pied_Kingfisher": 179,
#     "082.Ringed_Kingfisher": 127,
#     "083.White_breasted_Kingfisher": 194,
#     "084.Red_legged_Kittiwake": 45,
#     "085.Horned_Lark": 46,
#     "086.Pacific_Loon": 47,
#     "087.Mallard": 128,
#     "088.Western_Meadowlark": 165,
#     "089.Hooded_Merganser": 48,
#     "090.Red_breasted_Merganser": 49,
#     "091.Mockingbird": 50,
#     "092.Nighthawk": 129,
#     "093.Clark_Nutcracker": 130,
#     "094.White_breasted_Nuthatch": 51,
#     "095.Baltimore_Oriole": 131,
#     "096.Hooded_Oriole": 52,
#     "097.Orchard_Oriole": 132,
#     "098.Scott_Oriole": 53,
#     "099.Ovenbird": 54,
#     "100.Brown_Pelican": 55,
#     "101.White_Pelican": 56,
#     "102.Western_Wood_Pewee": 57,
#     "103.Sayornis": 58,
#     "104.American_Pipit": 59,
#     "105.Whip_poor_Will": 60,
#     "106.Horned_Puffin": 61,
#     "107.Common_Raven": 62,
#     "108.White_necked_Raven": 63,
#     "109.American_Redstart": 133,
#     "110.Geococcyx": 64,
#     "111.Loggerhead_Shrike": 65,
#     "112.Great_Grey_Shrike": 66,
#     "113.Baird_Sparrow": 67,
#     "114.Black_throated_Sparrow": 68,
#     "115.Brewer_Sparrow": 69,
#     "116.Chipping_Sparrow": 70,
#     "117.Clay_colored_Sparrow": 71,
#     "118.House_Sparrow": 72,
#     "119.Field_Sparrow": 166,
#     "120.Fox_Sparrow": 73,
#     "121.Grasshopper_Sparrow": 134,
#     "122.Harris_Sparrow": 74,
#     "123.Henslow_Sparrow": 75,
#     "124.Le_Conte_Sparrow": 76,
#     "125.Lincoln_Sparrow": 77,
#     "126.Nelson_Sharp_tailed_Sparrow": 180,
#     "127.Savannah_Sparrow": 181,
#     "128.Seaside_Sparrow": 167,
#     "129.Song_Sparrow": 78,
#     "130.Tree_Sparrow": 182,
#     "131.Vesper_Sparrow": 135,
#     "132.White_crowned_Sparrow": 79,
#     "133.White_throated_Sparrow": 136,
#     "134.Cape_Glossy_Starling": 80,
#     "135.Bank_Swallow": 81,
#     "136.Barn_Swallow": 168,
#     "137.Cliff_Swallow": 169,
#     "138.Tree_Swallow": 137,
#     "139.Scarlet_Tanager": 138,
#     "140.Summer_Tanager": 82,
#     "141.Artic_Tern": 139,
#     "142.Black_Tern": 83,
#     "143.Caspian_Tern": 84,
#     "144.Common_Tern": 197,
#     "145.Elegant_Tern": 140,
#     "146.Forsters_Tern": 85,
#     "147.Least_Tern": 141,
#     "148.Green_tailed_Towhee": 86,
#     "149.Brown_Thrasher": 87,
#     "150.Sage_Thrasher": 170,
#     "151.Black_capped_Vireo": 88,
#     "152.Blue_headed_Vireo": 89,
#     "153.Philadelphia_Vireo": 90,
#     "154.Red_eyed_Vireo": 190,
#     "155.Warbling_Vireo": 183,
#     "156.White_eyed_Vireo": 142,
#     "157.Yellow_throated_Vireo": 91,
#     "158.Bay_breasted_Warbler": 143,
#     "159.Black_and_white_Warbler": 92,
#     "160.Black_throated_Blue_Warbler": 93,
#     "161.Blue_winged_Warbler": 144,
#     "162.Canada_Warbler": 191,
#     "163.Cape_May_Warbler": 171,
#     "164.Cerulean_Warbler": 94,
#     "165.Chestnut_sided_Warbler": 172,
#     "166.Golden_winged_Warbler": 145,
#     "167.Hooded_Warbler": 184,
#     "168.Kentucky_Warbler": 95,
#     "169.Magnolia_Warbler": 192,
#     "170.Mourning_Warbler": 146,
#     "171.Myrtle_Warbler": 173,
#     "172.Nashville_Warbler": 185,
#     "173.Orange_crowned_Warbler": 186,
#     "174.Palm_Warbler": 96,
#     "175.Pine_Warbler": 97,
#     "176.Prairie_Warbler": 98,
#     "177.Prothonotary_Warbler": 147,
#     "178.Swainson_Warbler": 99,
#     "179.Tennessee_Warbler": 193,
#     "180.Wilson_Warbler": 100,
#     "181.Worm_eating_Warbler": 148,
#     "182.Yellow_Warbler": 174,
#     "183.Northern_Waterthrush": 149,
#     "184.Louisiana_Waterthrush": 101,
#     "185.Bohemian_Waxwing": 102,
#     "186.Cedar_Waxwing": 103,
#     "187.American_Three_toed_Woodpecker": 104,
#     "188.Pileated_Woodpecker": 150,
#     "189.Red_bellied_Woodpecker": 105,
#     "190.Red_cockaded_Woodpecker": 106,
#     "191.Red_headed_Woodpecker": 187,
#     "192.Downy_Woodpecker": 151,
#     "193.Bewick_Wren": 107,
#     "194.Cactus_Wren": 175,
#     "195.Carolina_Wren": 152,
#     "196.House_Wren": 198,
#     "197.Marsh_Wren": 153,
#     "198.Rock_Wren": 176,
#     "199.Winter_Wren": 154,
#     "200.Common_Yellowthroat": 108
#   },
#   "layer_norm_eps": 1e-05,
#   "mlp_ratio": 4.0,
#   "model_type": "swin",
#   "num_channels": 3,
#   "num_heads": [
#     3,
#     6,
#     12,
#     24
#   ],
#   "num_layers": 4,
#   "patch_size": 4,
#   "path_norm": true,
#   "problem_type": "single_label_classification",
#   "qkv_bias": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "use_absolute_embeddings": false,
#   "window_size": 7
# }
#
# loading weights file images_model/pytorch_model.bin
# Some weights of the model checkpoint at images_model were not used when initializing SwinModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing SwinModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing SwinModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of SwinModel were initialized from the model checkpoint at images_model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use SwinModel for predictions without further training.

# %%
from PIL import Image

image = "CUB/images/001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg"
image = Image.open(image)
inputs = feature_extractor(image, return_tensors="pt")
outputs = model(**inputs)
embeddings = outputs.pooler_output.detach().numpy()
embeddings
# Out:
# array([[-2.87666655e+00, -1.54505777e+00, -2.45201278e+00,
#         -5.26990235e-01, -1.83339751e+00, -1.91038632e+00,
#         -5.78864336e-01, -9.61026400e-02, -2.85229421e+00,
#          4.29796308e-01,  1.93491304e+00, -1.38537121e+00,
#         -1.86850235e-01,  2.56764698e+00, -1.32818294e+00,
#         -1.49791002e+00, -3.99746656e-01,  6.20913124e+00,
#          7.22235024e-01, -5.73959768e-01, -2.03035808e+00,
#         -1.94549516e-01, -5.59067249e-01, -1.64629209e+00,
#         -2.14182401e+00,  2.02764124e-01, -2.45545745e+00,
#          1.68615890e+00, -2.24219680e+00, -2.82706231e-01,
#          1.76093841e+00, -3.12196112e+00, -1.98074415e-01,
#         -6.25642717e-01, -8.96991253e-01,  5.28155684e-01,
#         -3.03578004e-02, -1.04759109e+00,  4.96165943e+00,
#         -8.77918661e-01, -2.91563034e-01, -9.03934002e-01,
#         -1.78477794e-01,  4.08603519e-01,  7.57297933e-01,
#          1.37821794e+00,  7.83613861e-01, -3.83153677e+00,
#          2.14251781e+00, -4.25525963e-01, -1.96880293e+00,
#         -2.77558297e-01,  1.90099049e+00,  6.53681383e-02,
